# %%
import pandas as pd  # used for data manupulation
import numpy as np
import matplotlib.pyplot as plt   #used for data visualization
import seaborn as sns    #used for data visualization
import squarify       #used for data visualization

# %%
data = pd.read_csv('../input/masterclass/Walmart.csv')
data

# %%
data.head()

# %%
data.describe()

# %%
data.columns

# %%
data.tail()

# %%
data.info()

# %%
data.isnull().sum()

# %%
plt.figure(figsize = (20,8))
data['Sales'].plot()
data['Profit'].plot()

# %%
plt.figure(figsize = (20,8))
sns.scatterplot(data['Sales'],data['Profit'])

# %%
data = pd.read_csv('../input/masterclass/Pollution.csv')
top = data.head(7)
top

# %%
plt.figure(figsize = (20,8))
plt.barh(top['Country Name'], top['CO2'])

# %%
 # plt.figure(figsize = (20,8))
squarify.plot(top['Methane'], label=top['Country Name'])  #Tree Map

# %%
data.dropna(how = 'all') #Data Cleansing

# %%
data.columns

# %%
data['Country Name'].replace({'United States':'USA'}, inplace =True)
data['Country Name'].unique()
